# %%
import matplotlib.pyplot as plt
import cv2

# %%
img=cv2.imread('plastic peg.jpg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
#Preprocessing 
def preprocessing(img):
    height=220
    width=220
    dim=(width,height)
    #res_img=[]
    res=cv2.resize(img,dim,interpolation=cv2.INTER_LINEAR)
    #res_img.append(res)
    print("RESIZED",res)
    plt.imshow(cv2.cvtColor(res,cv2.COLOR_BGR2RGB))
    
preprocessing(img)
# Out:
# RESIZED [[[228 221 218]
#   [228 221 218]
#   [229 222 219]
#   ...
#   [228 221 218]
#   [228 221 218]
#   [228 221 218]]
#
#  [[228 221 218]
#   [228 221 218]
#   [229 222 219]
#   ...
#   [228 221 218]
#   [228 221 218]
#   [228 221 218]]
#
#  [[229 222 219]
#   [229 222 219]
#   [229 222 219]
#   ...
#   [229 222 219]
#   [228 221 218]
#   [228 221 218]]
#
#  ...
#
#  [[226 220 215]
#   [226 220 215]
#   [227 221 216]
#   ...
#   [228 221 218]
#   [228 221 218]
#   [228 221 218]]
#
#  [[226 220 215]
#   [226 220 215]
#   [227 221 216]
#   ...
#   [228 221 218]
#   [227 220 217]
#   [227 220 217]]
#
#  [[226 220 215]
#   [226 220 215]
#   [227 221 216]
#   ...
#   [228 221 218]
#   [227 220 217]
#   [227 220 217]]]
